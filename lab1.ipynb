# %%
import numpy as np
import pandas as pd
df = pd.read_csv('https://query.data.world/s/32tfmhwuq4vtfda5ykqixlqnixj2jx')

# %%
data = pd.DataFrame(df)

# %%
data.head()
# Out:
#    PEOPLE_POSITIVE_CASES_COUNT COUNTY_NAME PROVINCE_STATE_NAME REPORT_DATE  \
# 0                           42    Chariton            Missouri  2020-09-13
# 1                            6    Chariton            Missouri  2020-07-06
# 2                            6    Chariton            Missouri  2020-05-22
# 3                          224    Chariton            Missouri  2020-11-24
# 4                          221    Chariton            Missouri  2020-11-23
#
#   CONTINENT_NAME DATA_SOURCE_NAME  PEOPLE_DEATH_NEW_COUNT  COUNTY_FIPS_NUMBER  \
# 0        America   New York Times                       0             29041.0
# 1        America   New York Times                       0             29041.0
# 2        America   New York Times                       0             29041.0
# 3        America   New York Times                       0             29041.0
# 4        America   New York Times                       0             29041.0
#
#   COUNTRY_ALPHA_3_CODE COUNTRY_SHORT_NAME COUNTRY_ALPHA_2_CODE  \
# 0                  USA      United States                   US
# 1                  USA      United States                   US
# 2                  USA      United States                   US
# 3                  USA      United States                   US
# 4                  USA      United States                   US
#
#    PEOPLE_POSITIVE_NEW_CASES_COUNT  PEOPLE_DEATH_COUNT
# 0                                2                   0
# 1                                0                   0
# 2                                0                   0
# 3                                3                   0
# 4                                2                   0

# %%
data = data.drop(['COUNTY_NAME','PROVINCE_STATE_NAME'], axis=1)

# %%
data.head()
# Out:
#    PEOPLE_POSITIVE_CASES_COUNT REPORT_DATE CONTINENT_NAME DATA_SOURCE_NAME  \
# 0                           42  2020-09-13        America   New York Times
# 1                            6  2020-07-06        America   New York Times
# 2                            6  2020-05-22        America   New York Times
# 3                          224  2020-11-24        America   New York Times
# 4                          221  2020-11-23        America   New York Times
#
#    PEOPLE_DEATH_NEW_COUNT  COUNTY_FIPS_NUMBER COUNTRY_ALPHA_3_CODE  \
# 0                       0             29041.0                  USA
# 1                       0             29041.0                  USA
# 2                       0             29041.0                  USA
# 3                       0             29041.0                  USA
# 4                       0             29041.0                  USA
#
#   COUNTRY_SHORT_NAME COUNTRY_ALPHA_2_CODE  PEOPLE_POSITIVE_NEW_CASES_COUNT  \
# 0      United States                   US                                2
# 1      United States                   US                                0
# 2      United States                   US                                0
# 3      United States                   US                                3
# 4      United States                   US                                2
#
#    PEOPLE_DEATH_COUNT
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %%
data = data.drop(['DATA_SOURCE_NAME','PEOPLE_DEATH_NEW_COUNT','COUNTY_FIPS_NUMBER','COUNTRY_ALPHA_3_CODE'], axis=1)

# %%
data.head()
# Out:
#    PEOPLE_POSITIVE_CASES_COUNT REPORT_DATE CONTINENT_NAME COUNTRY_SHORT_NAME  \
# 0                           42  2020-09-13        America      United States
# 1                            6  2020-07-06        America      United States
# 2                            6  2020-05-22        America      United States
# 3                          224  2020-11-24        America      United States
# 4                          221  2020-11-23        America      United States
#
#   COUNTRY_ALPHA_2_CODE  PEOPLE_POSITIVE_NEW_CASES_COUNT  PEOPLE_DEATH_COUNT
# 0                   US                                2                   0
# 1                   US                                0                   0
# 2                   US                                0                   0
# 3                   US                                3                   0
# 4                   US                                2                   0

# %%
data = data.drop(['COUNTRY_ALPHA_2_CODE','PEOPLE_POSITIVE_NEW_CASES_COUNT','PEOPLE_DEATH_COUNT'],axis=1)

# %%
data
# Out:
#          PEOPLE_POSITIVE_CASES_COUNT REPORT_DATE CONTINENT_NAME  \
# 0                                 42  2020-09-13        America
# 1                                  6  2020-07-06        America
# 2                                  6  2020-05-22        America
# 3                                224  2020-11-24        America
# 4                                221  2020-11-23        America
# ...                              ...         ...            ...
# 1303819                          558  2020-11-24         Africa
# 1303820                          558  2020-11-23         Africa
# 1303821                           39  2020-04-21         Africa
# 1303822                           34  2020-04-13         Africa
# 1303823                            0  2020-03-12         Africa
#
#         COUNTRY_SHORT_NAME
# 0            United States
# 1            United States
# 2            United States
# 3            United States
# 4            United States
# ...                    ...
# 1303819            Eritrea
# 1303820            Eritrea
# 1303821            Eritrea
# 1303822            Eritrea
# 1303823            Eritrea
#
# [1303824 rows x 4 columns]

# %%
data.CONTINENT_NAME.unique()
# Out:
# array(['America', 'Africa', 'Asia', 'Europe', 'Oceania', nan],
#       dtype=object)

# %%
data1 = data.loc[data['CONTINENT_NAME']=='Oceania']
data2 = data.loc[data['CONTINENT_NAME']=='Asia']
d = data.loc[data['CONTINENT_NAME']=='Europe']
data2 = data2.append(d)
data3 = data.loc[data['CONTINENT_NAME']=='America']

# %%
data1
# Out:
#          PEOPLE_POSITIVE_CASES_COUNT REPORT_DATE CONTINENT_NAME  \
# 1149103                            0  2020-07-25        Oceania
# 1149104                           17  2021-01-03        Oceania
# 1149105                            3  2020-10-20        Oceania
# 1149106                            0  2020-07-02        Oceania
# 1149107                            0  2020-06-28        Oceania
# ...                              ...         ...            ...
# 1301773                          572  2020-12-28        Oceania
# 1301774                          444  2020-07-18        Oceania
# 1301775                          562  2020-12-06        Oceania
# 1301776                          522  2020-11-14        Oceania
# 1301777                          443  2020-06-30        Oceania
#
#         COUNTRY_SHORT_NAME
# 1149103    Solomon Islands
# 1149104    Solomon Islands
# 1149105    Solomon Islands
# 1149106    Solomon Islands
# 1149107    Solomon Islands
# ...                    ...
# 1301773          Australia
# 1301774          Australia
# 1301775          Australia
# 1301776          Australia
# 1301777          Australia
#
# [6256 rows x 4 columns]

# %%
data2
# Out:
#          PEOPLE_POSITIVE_CASES_COUNT REPORT_DATE CONTINENT_NAME  \
# 1121977                            0  2020-02-29           Asia
# 1121978                            0  2020-02-01           Asia
# 1121979                            0  2020-01-27           Asia
# 1121980                          174  2021-01-16           Asia
# 1121981                          152  2020-12-26           Asia
# ...                              ...         ...            ...
# 1303245                            0  2020-01-21         Europe
# 1303249                            0  2020-01-21         Europe
# 1303250                            0  2020-01-21         Europe
# 1303253                            0  2020-01-21         Europe
# 1303267                            0  2020-01-21         Europe
#
#         COUNTRY_SHORT_NAME
# 1121977             Brunei
# 1121978             Brunei
# 1121979             Brunei
# 1121980             Brunei
# 1121981             Brunei
# ...                    ...
# 1303245      Liechtenstein
# 1303249            Czechia
# 1303250             Kosovo
# 1303253        Switzerland
# 1303267              Spain
#
# [47104 rows x 4 columns]

# %%
data3
# Out:
#          PEOPLE_POSITIVE_CASES_COUNT REPORT_DATE CONTINENT_NAME  \
# 0                                 42  2020-09-13        America
# 1                                  6  2020-07-06        America
# 2                                  6  2020-05-22        America
# 3                                224  2020-11-24        America
# 4                                221  2020-11-23        America
# ...                              ...         ...            ...
# 1303243                            0  2020-01-21        America
# 1303244                            0  2020-01-21        America
# 1303255                            0  2020-01-21        America
# 1303265                            0  2020-01-21        America
# 1303266                            0  2020-01-21        America
#
#         COUNTRY_SHORT_NAME
# 0            United States
# 1            United States
# 2            United States
# 3            United States
# 4            United States
# ...                    ...
# 1303243             Canada
# 1303244            Bahamas
# 1303255          Guatemala
# 1303265               Peru
# 1303266              Chile
#
# [1229120 rows x 4 columns]

# %%
d = data1.groupby('COUNTRY_SHORT_NAME')
d2 = data2.groupby('COUNTRY_SHORT_NAME')
d3 = data3.groupby('COUNTRY_SHORT_NAME')

# %%
d.head()
# Out:
#          PEOPLE_POSITIVE_CASES_COUNT REPORT_DATE CONTINENT_NAME  \
# 1149103                            0  2020-07-25        Oceania
# 1149104                           17  2021-01-03        Oceania
# 1149105                            3  2020-10-20        Oceania
# 1149106                            0  2020-07-02        Oceania
# 1149107                            0  2020-06-28        Oceania
# 1162072                         1556  2020-07-25        Oceania
# 1162073                         2181  2021-01-03        Oceania
# 1162074                         1912  2020-10-20        Oceania
# 1162075                         1530  2020-07-02        Oceania
# 1162076                         1528  2020-06-28        Oceania
# 1203803                           62  2020-07-25        Oceania
# 1203804                        16926  2021-01-03        Oceania
# 1203805                         4548  2020-10-20        Oceania
# 1203806                           62  2020-07-02        Oceania
# 1203807                           62  2020-06-28        Oceania
# 1204059                            0  2020-01-21        Oceania
# 1204060                            0  2020-01-21        Oceania
# 1204062                            0  2020-01-21        Oceania
# 1205683                            0  2020-01-21        Oceania
# 1211205                           16  2020-04-15        Oceania
# 1211206                           15  2020-04-08        Oceania
# 1211207                           26  2020-07-13        Oceania
# 1211208                           21  2020-07-08        Oceania
# 1211209                            5  2020-03-28        Oceania
# 1213486                         8181  2020-07-25        Oceania
# 1213487                        20395  2021-01-03        Oceania
# 1213488                        20323  2020-10-20        Oceania
# 1216916                            0  2020-07-25        Oceania
# 1216917                            1  2021-01-03        Oceania
# 1216918                            0  2020-10-20        Oceania
# 1216919                            0  2020-07-02        Oceania
# 1216920                            0  2020-06-28        Oceania
# 1217338                            0  2020-01-21        Oceania
# 1223419                            0  2020-07-25        Oceania
# 1223420                            4  2021-01-03        Oceania
# 1223421                            0  2020-10-20        Oceania
# 1223422                            0  2020-07-02        Oceania
# 1229246                            0  2020-01-21        Oceania
# 1254446                           27  2020-09-26        Oceania
# 1254447                           23  2020-08-15        Oceania
# 1254448                           22  2020-07-28        Oceania
# 1254449                           27  2020-10-07        Oceania
# 1279094                            0  2020-07-25        Oceania
# 1279095                            2  2021-01-03        Oceania
# 1279096                            0  2020-10-20        Oceania
# 1279097                            0  2020-07-02        Oceania
# 1287508                           39  2020-07-25        Oceania
# 1287509                          799  2021-01-03        Oceania
# 1287510                          581  2020-10-20        Oceania
# 1287511                           11  2020-07-02        Oceania
#
#         COUNTRY_SHORT_NAME
# 1149103    Solomon Islands
# 1149104    Solomon Islands
# 1149105    Solomon Islands
# 1149106    Solomon Islands
# 1149107    Solomon Islands
# 1162072        New Zealand
# 1162073        New Zealand
# 1162074        New Zealand
# 1162075        New Zealand
# 1162076        New Zealand
# 1203803   French Polynesia
# 1203804   French Polynesia
# 1203805   French Polynesia
# 1203806   French Polynesia
# 1203807   French Polynesia
# 1204059   Papua New Guinea
# 1204060          Australia
# 1204062      New Caledonia
# 1205683          Australia
# 1211205               Fiji
# 1211206               Fiji
# 1211207               Fiji
# 1211208               Fiji
# 1211209               Fiji
# 1213486          Australia
# 1213487          Australia
# 1213488          Australia
# 1216916            Vanuatu
# 1216917            Vanuatu
# 1216918            Vanuatu
# 1216919            Vanuatu
# 1216920            Vanuatu
# 1217338   Marshall Islands
# 1223419   Marshall Islands
# 1223420   Marshall Islands
# 1223421   Marshall Islands
# 1223422   Marshall Islands
# 1229246              Samoa
# 1254446      New Caledonia
# 1254447      New Caledonia
# 1254448      New Caledonia
# 1254449      New Caledonia
# 1279094              Samoa
# 1279095              Samoa
# 1279096              Samoa
# 1279097              Samoa
# 1287508   Papua New Guinea
# 1287509   Papua New Guinea
# 1287510   Papua New Guinea
# 1287511   Papua New Guinea

# %%
mean1 = d.mean()
mean2 = d2.mean()
mean3 = d3.mean()

# %%
mean1
# Out:
#                     PEOPLE_POSITIVE_CASES_COUNT
# COUNTRY_SHORT_NAME
# Australia                           1943.308084
# Fiji                                  23.951087
# French Polynesia                    3817.891304
# Marshall Islands                       0.804348
# New Caledonia                         21.160326
# New Zealand                         1413.964674
# Papua New Guinea                     278.527174
# Samoa                                  0.334239
# Solomon Islands                        3.929348
# Vanuatu                                0.201087

# %%
mean2
# Out:
#                     PEOPLE_POSITIVE_CASES_COUNT
# COUNTRY_SHORT_NAME
# Afghanistan                        26251.005435
# Albania                            13977.554348
# Andorra                             2376.663043
# Armenia                            49269.366848
# Austria                            83074.331522
# ...                                         ...
# United Kingdom                    656008.437500
# Uzbekistan                         30958.562500
# Vietnam                              686.834239
# West Bank and Gaza                 32633.214674
# Yemen                               1164.866848
#
# [96 rows x 1 columns]

# %%
mean3
# Out:
#                                   PEOPLE_POSITIVE_CASES_COUNT
# COUNTRY_SHORT_NAME
# Anguilla                                         3.760870e+00
# Antigua and Barbuda                              7.273370e+01
# Argentina                                        5.070462e+05
# Aruba                                            1.919133e+03
# Bahamas                                          2.580084e+03
# Barbados                                         1.754212e+02
# Belize                                           2.238598e+03
# Bermuda                                          1.800082e+02
# Bolivia                                          7.210165e+04
# Bonaire, Sint Eustatius and Saba                 5.812500e+01
# Brazil                                           2.910438e+06
# British Virgin Islands                           3.381250e+01
# Canada                                           1.142048e+04
# Cayman Islands                                   1.670000e+02
# Chile                                            2.899813e+05
# Colombia                                         5.305637e+05
# Costa Rica                                       5.017700e+04
# Cuba                                             4.196867e+03
# Curacao                                          7.776196e+02
# Dominica                                         3.126902e+01
# Dominican Republic                               6.858011e+04
# Ecuador                                          9.013861e+04
# El Salvador                                      1.761574e+04
# Falkland Islands (Malvinas)                      1.205707e+01
# French Guiana                                    5.812484e+03
# Greenland                                        1.285326e+01
# Grenada                                          3.047826e+01
# Guadeloupe                                       2.829000e+03
# Guatemala                                        5.351681e+04
# Guyana                                           1.889573e+03
# Haiti                                            5.279342e+03
# Honduras                                         4.691818e+04
# Jamaica                                          3.946516e+03
# Martinique                                       1.606209e+03
# Mexico                                           4.983766e+05
# Montserrat                                       9.866848e+00
# Nicaragua                                        2.941076e+03
# Panama                                           7.868964e+04
# Paraguay                                         2.925393e+04
# Peru                                             4.552087e+05
# Saint Barthelemy                                 4.821467e+01
# Saint Kitts and Nevis                            1.545109e+01
# Saint Lucia                                      8.255978e+01
# Saint Pierre and Miquelon                        6.581522e+00
# Saint Vincent and the Grenadines                 5.808152e+01
# Sint Maarten                                     4.376141e+02
# St Martin                                        2.774429e+02
# Suriname                                         2.480486e+03
# Trinidad and Tobago                              2.327473e+03
# Turks and Caicos Islands                         3.318478e+02
# United States                                    1.847939e+03
# Uruguay                                          3.719451e+03
# Venezuela                                        4.045367e+04

# %%
med1 = d.median()
med2 = d2.median()
med3 = d3.median()

# %%
med1
# Out:
#                     PEOPLE_POSITIVE_CASES_COUNT
# COUNTRY_SHORT_NAME
# Australia                                 438.0
# Fiji                                       27.0
# French Polynesia                           62.0
# Marshall Islands                            0.0
# New Caledonia                              22.0
# New Zealand                              1555.5
# Papua New Guinea                           30.5
# Samoa                                       0.0
# Solomon Islands                             0.0
# Vanuatu                                     0.0

# %%
med2
# Out:
#                     PEOPLE_POSITIVE_CASES_COUNT
# COUNTRY_SHORT_NAME
# Afghanistan                             35817.5
# Albania                                  4412.0
# Andorra                                   889.0
# Armenia                                 35927.5
# Austria                                 20014.0
# ...                                         ...
# United Kingdom                         296761.5
# Uzbekistan                              18682.5
# Vietnam                                   410.0
# West Bank and Gaza                       9571.0
# Yemen                                    1647.0
#
# [96 rows x 1 columns]

# %%
med3
# Out:
#                                   PEOPLE_POSITIVE_CASES_COUNT
# COUNTRY_SHORT_NAME
# Anguilla                                                  3.0
# Antigua and Barbuda                                      76.0
# Argentina                                            144963.5
# Aruba                                                   117.0
# Bahamas                                                 246.5
# Barbados                                                106.0
# Belize                                                   45.0
# Bermuda                                                 153.0
# Bolivia                                               64693.5
# Bonaire, Sint Eustatius and Saba                         10.0
# Brazil                                              2257494.5
# British Virgin Islands                                    8.0
# Canada                                                  120.0
# Cayman Islands                                          203.0
# Chile                                                337580.5
# Colombia                                             222400.5
# Costa Rica                                            12745.0
# Cuba                                                   2464.0
# Curacao                                                  28.0
# Dominica                                                 18.0
# Dominican Republic                                    56829.0
# Ecuador                                               77702.5
# El Salvador                                           13176.0
# Falkland Islands (Malvinas)                              13.0
# French Guiana                                          6984.5
# Greenland                                                13.0
# Grenada                                                  23.0
# Guadeloupe                                              195.0
# Guatemala                                             41663.5
# Guyana                                                  350.5
# Haiti                                                  7182.0
# Honduras                                              36502.0
# Jamaica                                                 818.5
# Martinique                                              262.0
# Mexico                                               366493.0
# Montserrat                                               12.0
# Nicaragua                                              3439.0
# Panama                                                56361.5
# Paraguay                                               4056.5
# Peru                                                 368823.0
# Saint Barthelemy                                          6.0
# Saint Kitts and Nevis                                    17.0
# Saint Lucia                                              23.5
# Saint Pierre and Miquelon                                 4.0
# Saint Vincent and the Grenadines                         52.0
# Sint Maarten                                             80.0
# St Martin                                                46.0
# Suriname                                               1205.0
# Trinidad and Tobago                                     141.0
# Turks and Caicos Islands                                 86.0
# United States                                           115.0
# Uruguay                                                1129.0
# Venezuela                                             13388.5

# %%
quan1 = d.quantile()
quan2 = d2.quantile()
quan3 = d3.quantile()

# %%
quan1

# %%
quan1

# %%
quan3

# %%
import matplotlib.pyplot as plt

# %%
data1.boxplot(figsize=(12,10), column=['PEOPLE_POSITIVE_CASES_COUNT'], by=['COUNTRY_SHORT_NAME'])
 
plt.show()

# %%
data2.boxplot(figsize=(12,10), column=['PEOPLE_POSITIVE_CASES_COUNT'], by=['COUNTRY_SHORT_NAME'])
 
plt.show()

# %%
data3.boxplot(figsize=(12,10), column=['PEOPLE_POSITIVE_CASES_COUNT'], by=['COUNTRY_SHORT_NAME'])
 
plt.show()
